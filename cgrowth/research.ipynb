# %% [markdown]
# ![QuantConnect Logo](https://cdn.quantconnect.com/web/i/icon.png)
# <hr>

# %%
# QuantBook Analysis Tool 
# For more information see [https://www.quantconnect.com/docs/v2/our-platform/research/getting-started]
qb = QuantBook()
spy = qb.add_equity("SPY")
# Locally Lean installs free sample data, to download more data please visit https://www.quantconnect.com/docs/v2/lean-cli/datasets/downloading-data 
qb.set_start_date(2013, 10, 11)
history = qb.history(qb.securities.keys(), 360, Resolution.DAILY)

# Indicator Analysis
bbdf = qb.indicator(BollingerBands(30, 2), spy.symbol, 360, Resolution.DAILY)
bbdf.drop('standarddeviation', axis=1).plot()
# Out:
# 20250906 16:06:37.459 TRACE:: QuantBook started; Is Python: True
# 20250906 16:06:37.492 TRACE:: Config.GetValue(): downloader-data-update-period - Using default value: 7
# 20250906 16:06:37.495 TRACE:: Config.Get(): Configuration key not found. Key: databases-refresh-period - Using default value: 1.00:00:00
# 20250906 16:06:37.788 TRACE:: Config.GetValue(): qb-data-hour - Using default value: 9
# 20250906 16:06:37.790 TRACE:: Config.Get(): Configuration key not found. Key: lean-manager-type - Using default value: LocalLeanManager
# 20250906 16:06:37.790 TRACE:: Config.Get(): Configuration key not found. Key: data-permission-manager - Using default value: DataPermissionManager
# 20250906 16:06:37.790 TRACE:: Config.Get(): Configuration key not found. Key: data-monitor - Using default value: QuantConnect.Data.DataMonitor
# 20250906 16:06:37.791 TRACE:: Config.GetValue(): zip-data-cache-provider - Using default value: 10
# 20250906 16:06:37.791 TRACE:: Config.Get(): Configuration key not found. Key: fundamental-data-provider - Using default value: CoarseFundamentalDataProvider
# 20250906 16:06:37.791 TRACE:: Config.GetValue(): scheduled-event-leaky-bucket-capacity - Using default value: 120
# 20250906 16:06:37.791 TRACE:: Config.GetValue(): scheduled-event-leaky-bucket-time-interval-minutes - Using default value: 1440
# 20250906 16:06:37.791 TRACE:: Config.GetValue(): scheduled-event-leaky-bucket-refill-amount - Using default value: 18
# 20250906 16:06:37.792 TRACE:: Config.GetValue(): algorithm-manager-time-loop-maximum - Using default value: 20
# 20250906 16:06:37.792 TRACE:: Config.GetValue(): storage-limit - Using default value: 10737418240
# 20250906 16:06:37.792 TRACE:: Config.GetValue(): storage-permissions - Using default value: Read=True Write=True Delete=True
# 20250906 16:06:37.793 TRACE:: LocalObjectStore.Initialize(): Storage Root: /Storage. StorageFileCount 9999999. StorageLimit 10240MB. StoragePermissions Read=True Write=True Delete=True
# 20250906 16:06:37.793 TRACE:: Config.GetValue(): zip-data-cache-provider - Using default value: 10
# 20250906 16:06:37.797 TRACE:: HistoryProviderManager.Initialize(): history providers [SubscriptionDataReaderHistoryProvider]
# 20250906 16:06:37.797 TRACE:: Config.GetValue(): deployment-target - Using default value: LocalPlatform
# 20250906 16:06:37.798 TRACE:: Config.GetValue(): qb-data-hour - Using default value: 9
# 20250906 16:06:37.799 TRACE:: Config.Get(): Configuration key not found. Key: lean-manager-type - Using default value: LocalLeanManager
# 20250906 16:06:37.800 TRACE:: Config.Get(): Configuration key not found. Key: data-permission-manager - Using default value: DataPermissionManager
# 20250906 16:06:37.800 TRACE:: Config.Get(): Configuration key not found. Key: data-monitor - Using default value: QuantConnect.Data.DataMonitor
# 20250906 16:06:37.800 TRACE:: Config.GetValue(): zip-data-cache-provider - Using default value: 10
# 20250906 16:06:37.800 TRACE:: Config.Get(): Configuration key not found. Key: fundamental-data-provider - Using default value: CoarseFundamentalDataProvider
# 20250906 16:06:37.800 TRACE:: Config.GetValue(): algorithm-manager-time-loop-maximum - Using default value: 20
# 20250906 16:06:37.801 TRACE:: Config.GetValue(): storage-limit - Using default value: 10737418240
# 20250906 16:06:37.801 TRACE:: Config.GetValue(): storage-permissions - Using default value: Read=True Write=True Delete=True
# 20250906 16:06:37.801 TRACE:: LocalObjectStore.Initialize(): Storage Root: /Storage. StorageFileCount 9999999. StorageLimit 10240MB. StoragePermissions Read=True Write=True Delete=True
# 20250906 16:06:37.801 TRACE:: Config.GetValue(): zip-data-cache-provider - Using default value: 10
# 20250906 16:06:37.801 TRACE:: HistoryProviderManager.Initialize(): history providers [SubscriptionDataReaderHistoryProvider]
# 20250906 16:06:37.801 TRACE:: Config.GetValue(): deployment-target - Using default value: LocalPlatform
# 20250906 16:06:37.848 TRACE:: Config.GetValue(): data-feed-workers-count - Using default value: 8
# 20250906 16:06:37.848 TRACE:: Config.GetValue(): data-feed-max-work-weight - Using default value: 400
# 20250906 16:06:37.849 TRACE:: WeightedWorkScheduler(): will use 8 workers and MaxWorkWeight is 400
# <Axes: >
